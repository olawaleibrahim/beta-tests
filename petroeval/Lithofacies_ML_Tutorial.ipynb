# %%
from sklearn.metrics import f1_score, accuracy_score
from plots import two_plots, four_plots
import pseudomodes as pds
import pandas as pd
import test_utils
# %matplotlib inline

# %%
df = pd.read_csv('hidden_test.csv.txt', sep=';')

# %%
facies = pds.DataHandlers(df)
df1 = facies.set_mnemonics()

# %%
facies = pds.PredictLabels(df1, 'DEPTH_MD')

# %%
predictions = facies.predict(0, df1.shape[0])
# Out:
# Shape of dataframe before augmentation: (122397, 22)
# Augmenting features...
# Shape of dataframe after augmentation: (122397, 88)
# Model 1, predicting...
# Model 2, predicting...
# Predictions complete!

# %%
facies.plot_lithofacies(df, predictions, log1='GR', log2='NPHI', 
                        log3='RHOB', log4='DTC', log5='RMED', depth_col='DEPTH_MD')

# %%
lithology_numbers = {30000: 0,
                        65030: 1,
                        65000: 2,
                        80000: 3,
                        74000: 4,
                        70000: 5,
                        70032: 6,
                        88000: 7,
                        86000: 8,
                        99000: 9,
                        90000: 10,
                        93000: 11}

# %%
labels = df.FORCE_2020_LITHOFACIES_LITHOLOGY

labels = labels.map(lithology_numbers)

# %%
test_utils.show_evaluation(predictions, labels)   # hidden test data
# Out:
# Default score: -0.4846
# Accuracy is: 80.05%
# F1 is: 81.75%
